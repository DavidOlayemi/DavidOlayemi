# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = 'drive/My Drive/Colab Notebooks/'

# %%
import pandas as pd
import numpy as np
import sqlite3
from IPython.core.display import display, HTML

# %%
df = pd.read_csv(path+'btc-market-price.csv', header=None, names=['TimeStamp', 'Price'], na_values=['','_','?'])

df.head(10)
# Out:
#              TimeStamp        Price
# 0  2017-04-02 00:00:00  1099.169125
# 1  2017-04-03 00:00:00  1141.813000
# 2  2017-04-04 00:00:00  1141.600363
# 3  2017-04-05 00:00:00  1133.079314
# 4  2017-04-06 00:00:00  1196.307937
# 5  2017-04-07 00:00:00  1190.454250
# 6  2017-04-08 00:00:00  1181.149838
# 7  2017-04-09 00:00:00  1208.800500
# 8  2017-04-10 00:00:00  1207.744875
# 9  2017-04-11 00:00:00  1226.617037

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TimeStamp  365 non-null    object
#  1   Price      365 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 5.8+ KB

# %%
pd.to_datetime(df['TimeStamp'])
# Out:
# 0     2017-04-02
# 1     2017-04-03
# 2     2017-04-04
# 3     2017-04-05
# 4     2017-04-06
#          ...
# 360   2018-03-28
# 361   2018-03-29
# 362   2018-03-30
# 363   2018-03-31
# 364   2018-04-01
# Name: TimeStamp, Length: 365, dtype: datetime64[ns]

# %%
df['TimeStamp'] = pd.to_datetime(df['TimeStamp'])

df.head(10)
# Out:
#    TimeStamp        Price
# 0 2017-04-02  1099.169125
# 1 2017-04-03  1141.813000
# 2 2017-04-04  1141.600363
# 3 2017-04-05  1133.079314
# 4 2017-04-06  1196.307937
# 5 2017-04-07  1190.454250
# 6 2017-04-08  1181.149838
# 7 2017-04-09  1208.800500
# 8 2017-04-10  1207.744875
# 9 2017-04-11  1226.617037

# %%
exam_df1 = path+'exam_review.csv'

# %%
exam_df = pd.read_csv(exam_df1, sep='>', decimal=',', skiprows=None, dtype={'first_name':'str', 'last_name':'str'})

exam_df.head()
# Out:
#   first_name last_name  age  math_score  french_score
# 0        Ray    Morley   18        68.0          75.0
# 1     Melvin     Scott   24        77.0          83.0
# 2     Amirah     Haley   22        92.0          67.0
# 3     Gerard     Mills   19        78.0          72.0
# 4        Amy    Grimes   23        91.0          81.0

# %%
exam_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   first_name    5 non-null      object
#  1   last_name     5 non-null      object
#  2   age           5 non-null      int64
#  3   math_score    5 non-null      float64
#  4   french_score  5 non-null      float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 328.0+ bytes

# %%
exam_df.to_csv('out.csv', index=None)

# %%
#exam_out = pd.read_csv(path+'out.csv')

# %%
conn = sqlite3.connect(path+'chinook.db')

db_df = pd.read_sql('SELECT * FROM employees;', conn, parse_dates=['BirthDate', 'HireDate'], index_col='EmployeeId')
db_df.head()
# Out:
#            LastName FirstName  ...                Fax                     Email
# EmployeeId                     ...
# 1             Adams    Andrew  ...  +1 (780) 428-3457    andrew@chinookcorp.com
# 2           Edwards     Nancy  ...  +1 (403) 262-3322     nancy@chinookcorp.com
# 3           Peacock      Jane  ...  +1 (403) 262-6712      jane@chinookcorp.com
# 4              Park  Margaret  ...  +1 (403) 263-4289  margaret@chinookcorp.com
# 5           Johnson     Steve  ...   1 (780) 836-9543     steve@chinookcorp.com
#
# [5 rows x 14 columns]

# %%
db_df[2:5]
# Out:
#            LastName FirstName  ...                Fax                     Email
# EmployeeId                     ...
# 3           Peacock      Jane  ...  +1 (403) 262-6712      jane@chinookcorp.com
# 4              Park  Margaret  ...  +1 (403) 263-4289  margaret@chinookcorp.com
# 5           Johnson     Steve  ...   1 (780) 836-9543     steve@chinookcorp.com
#
# [3 rows x 14 columns]

# %%
db_df.describe()
# Out:
#        ReportsTo
# count   7.000000
# mean    2.857143
# std     2.193063
# min     1.000000
# 25%     1.500000
# 50%     2.000000
# 75%     4.000000
# max     6.000000

# %%
db_df['ReportsTo'].isna().sum()
# Out:
# 1

# %%
db_df['ReportsTo'].mean()
# Out:
# 2.857142857142857

# %%
db_df['ReportsTo']>1.75
# Out:
# EmployeeId
# 1    False
# 2    False
# 3     True
# 4     True
# 5     True
# 6    False
# 7     True
# 8     True
# Name: ReportsTo, dtype: bool

# %%
#change data type of City to category
db_df['City']= db_df['City'].astype('category')

# %%
db_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8 entries, 1 to 8
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   LastName    8 non-null      object
#  1   FirstName   8 non-null      object
#  2   Title       8 non-null      object
#  3   ReportsTo   7 non-null      float64
#  4   BirthDate   8 non-null      datetime64[ns]
#  5   HireDate    8 non-null      datetime64[ns]
#  6   Address     8 non-null      object
#  7   City        8 non-null      category
#  8   State       8 non-null      object
#  9   Country     8 non-null      object
#  10  PostalCode  8 non-null      object
#  11  Phone       8 non-null      object
#  12  Fax         8 non-null      object
#  13  Email       8 non-null      object
# dtypes: category(1), datetime64[ns](2), float64(1), object(10)
# memory usage: 1008.0+ bytes

# %% [markdown]
# READ HTMAL TABLES

# %%
html_string = 'https://www.basketball-reference.com/leagues/NBA_2019_per_game.html'

# %%
#display(HTML(html_string))

nba = pd.read_html(html_string)

len(nba)
# Out:
# 1

# %%
nba_table = nba[0]

nba_table.head(25)
# Out:
#     Rk                  Player  Pos  Age   Tm  ...  STL  BLK  TOV   PF   PTS
# 0    1            Álex Abrines   SG   25  OKC  ...  0.5  0.2  0.5  1.7   5.3
# 1    2              Quincy Acy   PF   28  PHO  ...  0.1  0.4  0.4  2.4   1.7
# 2    3            Jaylen Adams   PG   22  ATL  ...  0.4  0.1  0.8  1.3   3.2
# 3    4            Steven Adams    C   25  OKC  ...  1.5  1.0  1.7  2.6  13.9
# 4    5             Bam Adebayo    C   21  MIA  ...  0.9  0.8  1.5  2.5   8.9
# 5    6               Deng Adel   SF   21  CLE  ...  0.1  0.2  0.3  0.7   1.7
# 6    7  DeVaughn Akoon-Purcell   SG   25  DEN  ...  0.3  0.0  0.3  0.6   1.0
# 7    8       LaMarcus Aldridge    C   33  SAS  ...  0.5  1.3  1.8  2.2  21.3
# 8    9            Rawle Alkins   SG   21  CHI  ...  0.1  0.0  0.8  0.7   3.7
# 9   10           Grayson Allen   SG   23  UTA  ...  0.2  0.2  0.9  1.2   5.6
# 10  11           Jarrett Allen    C   20  BRK  ...  0.5  1.5  1.3  2.3  10.9
# ...

# %%
nba_table.drop(range(22, nba_table.shape[0]+1, 20))
# Out:
#       Rk        Player Pos Age   Tm   G  GS  ...  TRB  AST  STL  BLK  TOV   PF   PTS
# 0      1  Álex Abrines  SG  25  OKC  31   2  ...  1.5  0.6  0.5  0.2  0.5  1.7   5.3
# 1      2    Quincy Acy  PF  28  PHO  10   0  ...  2.5  0.8  0.1  0.4  0.4  2.4   1.7
# 2      3  Jaylen Adams  PG  22  ATL  34   1  ...  1.8  1.9  0.4  0.1  0.8  1.3   3.2
# 3      4  Steven Adams   C  25  OKC  80  80  ...  9.5  1.6  1.5  1.0  1.7  2.6  13.9
# 4      5   Bam Adebayo   C  21  MIA  82  28  ...  7.3  2.2  0.9  0.8  1.5  2.5   8.9
# ..   ...           ...  ..  ..  ...  ..  ..  ...  ...  ...  ...  ...  ...  ...   ...
# 729  528  Tyler Zeller   C  29  MEM   4   1  ...  4.5  0.8  0.3  0.8  1.0  4.0  11.5
# 730  529    Ante Žižić   C  22  CLE  59  25  ...  5.4  0.9  0.2  0.4  1.0  1.9   7.8
# 731  530   Ivica Zubac   C  21  TOT  59  37  ...  6.1  1.1  0.2  0.9  1.2  2.3   8.9
# 732  530   Ivica Zubac   C  21  LAL  33  12  ...  4.9  0.8  0.1  0.8  1.0  2.2   8.5
# ...

# %%
nba_table.head(25)
# Out:
#     Rk                  Player  Pos  Age   Tm  ...  STL  BLK  TOV   PF   PTS
# 0    1            Álex Abrines   SG   25  OKC  ...  0.5  0.2  0.5  1.7   5.3
# 1    2              Quincy Acy   PF   28  PHO  ...  0.1  0.4  0.4  2.4   1.7
# 2    3            Jaylen Adams   PG   22  ATL  ...  0.4  0.1  0.8  1.3   3.2
# 3    4            Steven Adams    C   25  OKC  ...  1.5  1.0  1.7  2.6  13.9
# 4    5             Bam Adebayo    C   21  MIA  ...  0.9  0.8  1.5  2.5   8.9
# 5    6               Deng Adel   SF   21  CLE  ...  0.1  0.2  0.3  0.7   1.7
# 6    7  DeVaughn Akoon-Purcell   SG   25  DEN  ...  0.3  0.0  0.3  0.6   1.0
# 7    8       LaMarcus Aldridge    C   33  SAS  ...  0.5  1.3  1.8  2.2  21.3
# 8    9            Rawle Alkins   SG   21  CHI  ...  0.1  0.0  0.8  0.7   3.7
# 9   10           Grayson Allen   SG   23  UTA  ...  0.2  0.2  0.9  1.2   5.6
# 10  11           Jarrett Allen    C   20  BRK  ...  0.5  1.5  1.3  2.3  10.9
# ...

# %% [markdown]
# READING EXCEL FILE

# %%
xl = pd.read_excel(path+'products.xlsx')

xl.head()
# Out:
#              product_id  ...                                               name
# 0  AVphzgbJLJeJML43fA0o  ...  Sanus VLF410B1 10-Inch Super Slim Full-Motion ...
# 1  AVpgMuGwLJeJML43KY_c  ...  Boytone - 2500W 2.1-Ch. Home Theater System - ...
# 2  AVpe9FXeLJeJML43zHrq  ...           DENAQ - AC Adapter for TOSHIBA SATELLITE
# 3  AVpfVJXu1cnluZ0-iwTT  ...  DreamWave - Tremor Portable Bluetooth Speaker ...
# 4  AVphUeKeilAPnD_x3-Be  ...  NS-SP1800BL 5.1-Channel Home Theater System (B...
#
# [5 rows x 5 columns]

# %%
pd.read_excel(path+'products.xlsx', index_col=[0])
xl.head()
# Out:
#                        price  ...                                               name
# product_id                    ...
# AVphzgbJLJeJML43fA0o  104.99  ...  Sanus VLF410B1 10-Inch Super Slim Full-Motion ...
# AVpgMuGwLJeJML43KY_c   69.00  ...  Boytone - 2500W 2.1-Ch. Home Theater System - ...
# AVpe9FXeLJeJML43zHrq   23.99  ...           DENAQ - AC Adapter for TOSHIBA SATELLITE
# AVpfVJXu1cnluZ0-iwTT  290.99  ...  DreamWave - Tremor Portable Bluetooth Speaker ...
# AVphUeKeilAPnD_x3-Be  244.01  ...  NS-SP1800BL 5.1-Channel Home Theater System (B...
#
# [5 rows x 4 columns]

# %%
Products = pd.read_excel(path+'products.xlsx', sheet_name='Products', index_col='product_id')

Products.head()
# Out:
#                        price  ...                                               name
# product_id                    ...
# AVphzgbJLJeJML43fA0o  104.99  ...  Sanus VLF410B1 10-Inch Super Slim Full-Motion ...
# AVpgMuGwLJeJML43KY_c   69.00  ...  Boytone - 2500W 2.1-Ch. Home Theater System - ...
# AVpe9FXeLJeJML43zHrq   23.99  ...           DENAQ - AC Adapter for TOSHIBA SATELLITE
# AVpfVJXu1cnluZ0-iwTT  290.99  ...  DreamWave - Tremor Portable Bluetooth Speaker ...
# AVphUeKeilAPnD_x3-Be  244.01  ...  NS-SP1800BL 5.1-Channel Home Theater System (B...
#
# [5 rows x 4 columns]

# %%
Merchant= pd.read_excel(path+'products.xlsx', sheet_name='Merchants', index_col='merchant_id')

Merchant.head()
# Out:
#                      merchant
# merchant_id
# 1001              Bestbuy.com
# 1002              Walmart.com
# 1003              Bestbuy.com
# 1004                 Growkart
# 1005         bhphotovideo.com
